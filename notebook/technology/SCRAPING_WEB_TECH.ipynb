# %%
pip install setuptools==58
# Out:
# Collecting setuptools==58
#   Downloading setuptools-58.0.0-py3-none-any.whl.metadata (4.9 kB)
# Downloading setuptools-58.0.0-py3-none-any.whl (816 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.3/816.3 kB 33.6 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# arviz 0.20.0 requires setuptools>=60.0.0, but you have setuptools 58.0.0 which is incompatible.
# pytensor 2.26.3 requires setuptools>=59.0.0, but you have setuptools 58.0.0 which is incompatible.
# Successfully installed setuptools-58.0.0

# %%
pip install pygooglenews --upgrade
# Out:
# Collecting pygooglenews
#   Downloading pygooglenews-0.1.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from pygooglenews) (4.12.3)
# Collecting dateparser<0.8.0,>=0.7.6 (from pygooglenews)
#   Downloading dateparser-0.7.6-py2.py3-none-any.whl.metadata (26 kB)
# Collecting feedparser<6.0.0,>=5.2.1 (from pygooglenews)
#   Downloading feedparser-5.2.1.zip (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from pygooglenews) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->pygooglenews) (2.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2024.2)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.10/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2024.9.11)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.16.0)
# Downloading pygooglenews-0.1.2-py3-none-any.whl (10 kB)
# Downloading dateparser-0.7.6-py2.py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.0/362.0 kB 23.8 MB/s eta 0:00:00
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=45011 sha256=96883810470f9feb119c275b82d3dd1e30a773d82fc2a22de4a560ebc459a603
#   Stored in directory: /root/.cache/pip/wheels/35/49/00/0effa75eb79f1003f7e929da5f553ec09b485ed51e1ffceab3
# Successfully built feedparser
# Installing collected packages: feedparser, dateparser, pygooglenews
# Successfully installed dateparser-0.7.6 feedparser-5.2.1 pygooglenews-0.1.2

# %%
pip install feedparser==6.0.10
# Out:
# Collecting feedparser==6.0.10
#   Downloading feedparser-6.0.10-py3-none-any.whl.metadata (2.3 kB)
# Collecting sgmllib3k (from feedparser==6.0.10)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 7.3 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=b5ced76826ab86d110b2f34265b18751ea671408d66de449028162f986f8d074
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
#   Attempting uninstall: feedparser
#     Found existing installation: feedparser 5.2.1
#     Uninstalling feedparser-5.2.1:
#       Successfully uninstalled feedparser-5.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygooglenews 0.1.2 requires feedparser<6.0.0,>=5.2.1, but you have feedparser 6.0.10 which is incompatible.
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %%
from pygooglenews import GoogleNews

# %%
gn = GoogleNews()

# %%
technology = gn.topic_headlines('TECHNOLOGY', proxies=None, scraping_bee = None)

# %%
articles = technology['entries']  # Semua artikel
data = []

# %%
for article in articles:
    title = article.get('title', 'No title')
    source = article.get('source', {}).get('title', 'Unknown source')
    published = article.get('published', 'No date')
    link = article.get('link', 'No link')

    # Menambahkan data yang sudah dirapikan
    data.append({
        'Title': title,
        'Source': source,
        'Date': published,
        'URL': link
    })

# %%
import pandas as pd

# %%
# Membuat DataFrame untuk menyusun data
df = pd.DataFrame(data)

# Simpan data ke file CSV
output_path = "technology_news.csv"  # Ubah path sesuai kebutuhan
df.to_csv(output_path, index=False)

print(f"Data berhasil disimpan ke {output_path}")
# Out:
# Data berhasil disimpan ke technology_news.csv

# %%
print(technology)
# Out:
# {'feed': {'generator_detail': {'name': 'NFE/5.0'}, 'generator': 'NFE/5.0', 'title': 'Technology - Latest - Google News', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'Technology - Latest - Google News'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB?ceid=US:en&hl=en-US&gl=US'}], 'link': 'https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB?ceid=US:en&hl=en-US&gl=US', 'language': 'en-US', 'publisher': 'news-webmaster@google.com', 'publisher_detail': {'email': 'news-webmaster@google.com'}, 'rights': 'Copyright © 2024 Google. All rights reserved. This XML feed is made available solely for the purpose of rendering Google News results within a personal feed reader for personal, non-commercial use. Any other use of the feed is expressly prohibited. By accessing this feed or using these results in any manner whatsoever, you agree to be bound by the foregoing restrictions.', 'rights_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'Copyright © 2024 Google. All rights reserved. This XML feed is made available solely for the purpose of rendering Google News results within a personal feed reader for personal, non-commercial use. Any other use of the feed is expressly prohibited. By accessing this feed or using these results in any manner whatsoever, you agree to be bound by the foregoing restrictions.'}, 'updated': 'Fri, 29 Nov 2024 00:30:35 GMT', 'updated_parsed': time.struct_time(tm_year=2024, tm_mon=11, tm_mday=29, tm_hour=0, tm_min=30, tm_sec=35, tm_wday=4, tm_yday=334, tm_isdst=0), 'image': {'title': 'Google News', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'Google News'}, 'href': 'https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w256', 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.google.com/'}], 'link': 'https://news.google.com/', 'height': 256, 'width': 256}, 'subtitle': 'Google News', 'subtitle_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': 'Google News'}}, 'entries': [{'title': 'Microsoft Is Out of Its Mind, the Latest Surface Pro Crashes Below $850 on Black Friday - Gizmodo', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'Microsoft Is Out of Its Mind, the Latest Surface Pro Crashes Below $850 on Black Friday - Gizmodo'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.google.?oc=5'}], 'link': 'https://news.google.?oc=5', 'id': 'CBMitwFBVV95cUxQMHhiNnRYLTFMR1pkenZPN0RTNk9kVnFGdFYxVFVqaUs0NlhKaTVYQ1haMTAxU0VhVjlLWU51UlRzZGQ4NkpPWkhObEdRMy03YklCMmxuSW5ITmoyWExCQzJfUVVEVVdLT0RaWjF5R0ozd0xOREcwTXJpeXI0TDV6VjNydkEtNlVVUnpjS3JEcWRUU0UySFJGbi1qaVVyRUhpMlRyUjhVRGY1clU2dmNWaE1xOFFySnc', 'guidislink': False, 'published': 'Thu, 28 Nov 2024 18:30:03 GMT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=11, tm_mday=28, tm_hour=18, tm_min=30, tm_sec=3, tm_wday=3, tm_yday=333, tm_isdst=0), 'summary': '<ol><li><a href="https://news.google.?oc=5" target="_bla ...
